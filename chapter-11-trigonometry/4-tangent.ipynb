# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib.patches import Wedge

# %% [markdown]
# # §4 - The tangent
#
# [https://www.docdroid.net/K1VENuF/basic-mathematics-serge-lang-pdf#page=282]()
#
# ## The big ideas

# %% [markdown]
# ## Exercises
#
# ## 1
#
# Make a table for the values of the tangent at all points
#
# $\frac{n \pi}{4} \ \ \ \text{and} \ \ \ \frac{n \pi}{6}$
#
# with integers $n$ having the same values as in Exercises 1 of §2, except for those $n$ where the cosine is zero.  In your table, also make a column giving the values of the angle in degrees.
#
# ---
#
# _Completed using pencil and paper_
#
# ## 2
#
# Discuss how the tangent is increasing or decreasing for $-\frac{\pi}{2} \lt x \leq 0$.  Also for $\frac{\pi}{2} \lt x \lt \frac{3 \pi}{2}$ and $-\frac{3 \pi}{2} \lt x \lt - \frac{\pi}{2}$.
#
# ---
#
# Lets define the measure of the angle $A = x$ to avoid confusion for a coordinate.
#
# $-\frac{\pi}{2} \lt A \leq 0$ is the *fourth quadrant* of the unit circle.
#
# Let's imagine a ray from $O$ to a point $P = (0, -1)$ on the unit circle, which creates an angle of size $A = - \frac{\pi}{2}$.

# %%
circle = plt.Circle((0, 0), 1, color='black', fill=False)
fourth_quadrant = Wedge((0, 0), 1, -90, 0, hatch='/', fill=False)
P = (0, -1)

plt.gca().add_patch(circle)
plt.gca().add_patch(fourth_quadrant)
plt.gca().set_aspect('equal')
plt.xlim([-1.5, 1.5])
plt.ylim([-1.5, 1.5])
plt.plot(*P, 'o', color='black')
plt.annotate('P = (0, -1)', (P[0], P[1] - 0.3))
# Out:
# Text(0, -1.3, 'P = (0, -1)')

# %% [markdown]
# At the start of the range, $A = -\frac{\pi}{2}$, so
#
# $$
# \tan(A) = \frac{\sin(-\frac{\pi}{2})}{\cos(-\frac{\pi}{2})} = \frac{-1}{0} = \text{undefined}
# $$
#
# But if we move $P$ anticlockwise by a tiny amount by adding a _really small value_, $k$, to $A$, we get the first value of $\tan$ in the interval:
#
# $$
# \tan(-\frac{\pi}{2} + k) = \frac{\sin(-\frac{\pi}{2} + k)}{\cos(-\frac{\pi}{2} + k)} \approx \frac{-1}{k}
# $$
#
# We know from intuition that any number divided by a really small number is itself a really big number.
#
# So can intuit that $-\frac{1}{k}$ is a really big negative number, and that's where the value of $\tan$ in the interval $-\frac{\pi}{2} \lt x \leq 0$ starts.
#
# What happens when we keep increasing $k$?
#
# As $k$ tends towards $\frac{\pi}{2}$, $A$ tends towards $0$ (upper limit of the interval) and
#
# $$
# \lim_{k \to  \frac{\pi}{2}} = \begin{cases}
# \sin(-\frac{\pi}{2} + k) = 0 \\
# \cos(-\frac{\pi}{2} + k) = 1 \\
# \tan(-\frac{\pi}{2} + k) = 0
# \end{cases}
# $$
#
# We can draw show this in a table
#
# \begin{array} {|r|r|}
# \hline
# a & \sin a & \cos a & \tan a \\ \hline
# 0 & 0 & 1 & 0 \\ \hline
# -\frac{\pi}{6} & -\frac{1}{2} & \frac{\sqrt{3}}{2} & -\frac{\frac{1}{2}}{\frac{\sqrt{3}}{2}} = -\frac{1}{\sqrt{3}} \\ \hline
# -\frac{\pi}{4} & -\frac{1}{\sqrt{2}} & \frac{1}{\sqrt{2}} & -1 \\ \hline
# -\frac{2 \pi}{6} = -\frac{\pi}{3} & -\frac{\sqrt{3}}{2} & \frac{1}{2} & -\sqrt{3} \\ \hline
# -\frac{\pi}{2} & -1 & 0 & \frac{-1}{0} = \text{undefined} \\ \hline
# \end{array}
#
# And plot the values of the $\tan$ function next to the relevant points on the unit circle:

# %%
fig, (circle_ax, tan_ax) = plt.subplots(1, 2)
tan_ax.set_ylabel('tan a')
tan_ax.set_xlabel('a')
fig.subplots_adjust(wspace=0.5)

fig.suptitle('-pi/2 < x <= 0')

circle = plt.Circle((0, 0), 1, color='black', fill=False)
A = [
    - np.pi / 2,
    - np.pi / 3,
    - np.pi / 4,
    - np.pi / 6,
    0,
]
points = [(np.cos(a), np.sin(a)) for a in A]

circle_ax.add_patch(circle)
circle_ax.set_aspect('equal')
plt.xlim([- 4 * np.pi / 2, 4 * np.pi / 2])
plt.ylim([-2, 2])
for P in points:
    circle_ax.plot(*P, 'o', color='black')
    circle_ax.plot(*zip((0, 0), P), color='black', linestyle='dashed')

for a in A:
    tan_ax.plot(*(a, np.tan(a)), 'o', color='black')

x = np.linspace(*plt.xlim())
y = np.tan(x)
tan_ax.plot(x, y, color='black', linestyle='dashed')

# %% [markdown]
# Notice how in the fourth quadrant $\tan$ is negative.
#
# Also notice that $\tan a$ is $-1$ for $a = -\frac{\pi}{4}$, because $\sin(- \frac{\pi}{4})$ is the negation of $\cos(- \frac{\pi}{4})$.

# %%
fig, (circle_ax, tan_ax) = plt.subplots(1, 2)
tan_ax.set_ylabel('tan x')
tan_ax.set_xlabel('x')
fig.subplots_adjust(wspace=0.5)

fig.suptitle('pi/2 < x < 3pi/2')

circle = plt.Circle((0, 0), 1, color='black', fill=False)
A = [
    np.pi / 2,
    2 * np.pi / 3,
    3 * np.pi / 4,
    5 * np.pi / 6,
    np.pi,
    7 * np.pi / 6,
    5 * np.pi / 4,
    4 * np.pi / 3,
    3 * np.pi / 2
]
points = [(np.cos(a), np.sin(a)) for a in A]

circle_ax.add_patch(circle)
circle_ax.set_aspect('equal')
plt.xlim([- 4 * np.pi / 2, 4 * np.pi / 2])
plt.ylim([-2, 2])
for P in points:
    circle_ax.plot(*P, 'o', color='black')
    circle_ax.plot(*zip((0, 0), P), color='black', linestyle='dashed')

for a in A:
    tan_ax.plot(*(a, np.tan(a)), 'o', color='black')

x = np.linspace(*plt.xlim())
y = np.tan(x)
tan_ax.plot(x, y, color='black', linestyle='dashed')

# %% [markdown]
# Notice there are asymptotes at $a = \frac{\pi}{2}$ and $a = \frac{3 \pi}{2}$, again due to division by $0$ because $\cos(\frac{\pi}{2} = 0$.
#
# That the $\tan$ of $a = \frac{3\pi}{2}$ is an asymptote shouldn't surprise us because $a = \frac{3\pi}{2}$ and $a = -\frac{pi}{2}$ are _equivalent angles_.
#
# In between the asymptotes, we see that tan(a) is _increasing_ in the interval.
#
# Interestingly, the _rate_ of increase is itself decreasing in the first half and increasing in the second half, either side of an inflection point at $a = \pi$.
#
# We can see intuitively that the gradient is $0$ at these points of inflection.  Which is a nice piece of symmetry :-)

# %%
fig, (circle_ax, tan_ax) = plt.subplots(1, 2)
tan_ax.set_ylabel('tan x')
tan_ax.set_xlabel('x')
fig.subplots_adjust(wspace=0.5)

fig.suptitle('-3pi/2 < x < -pi/2')

circle = plt.Circle((0, 0), 1, color='black', fill=False)
A = [
    - 9 * np.pi / 6,
    - 8 * np.pi / 6,
    - 5 * np.pi / 4,
    - 7 * np.pi / 6,
    - np.pi,
    - 5 * np.pi / 6,
    - 3 * np.pi / 4,
    - 4 * np.pi / 6,
    - np.pi / 2
]
points = [(np.cos(a), np.sin(a)) for a in A]

circle_ax.add_patch(circle)
circle_ax.set_aspect('equal')
plt.xlim([- 4 * np.pi / 2, 4 * np.pi / 2])
plt.ylim([-2, 2])
for P in points:
    circle_ax.plot(*P, 'o', color='black')
    circle_ax.plot(*zip((0, 0), P), color='black', linestyle='dashed')

for a in A:
    tan_ax.plot(*(a, np.tan(a)), 'o', color='black')

x = np.linspace(*plt.xlim())
y = np.tan(x)
tan_ax.plot(x, y, color='black', linestyle='dashed')

# %% [markdown]
# ### 3
#
# Define the **cotangent** $\cot x = \frac{1}{\tan x}$.  Draw an approximate graph for the cotangent, i.e. for the points $(x, \cot x)$.

# %%
plt.xlim([- 4 * np.pi / 2, 4 * np.pi / 2])
plt.ylim([-2, 2])

x = np.linspace(*plt.xlim())
y_tan = np.tan(x)
y_tan[:-1][np.diff(y_tan) < 0] = np.nan
y_cot = 1 / np.tan(x)
y_cot[:-1][np.diff(y_cot) > 0] = np.nan

plt.plot(x, y_tan, linestyle='dashed', label='tan x')
plt.plot(x, y_cot, linestyle='dashed', label='cot x')
plt.legend()

# %% [markdown]
# ### 4
#
# Define the secant and cosecant by
#
# $$
# \sec x = \frac{1}{\cos x} \ \ \ \text{and} \ \ \ \operatorname{cosec} x = \frac{1}{sin x}
# $$
#
# for values of $x$ where $\cos x \neq 0$ and $\sin x \neq 0$, respectively.
#
# Find enough values of the secant and cosecant until you feel that you have the hang of things.  Draw their graphs.

# %%
# All calculated by memory

df = pd.DataFrame({
    'sin x': [
        0,  # horizontal
        1 / 2,
        1 / np.sqrt(2),
        np.sqrt(3) / 2,
        1,  # vertical
        np.sqrt(3) / 2,
        1 / np.sqrt(2),
        1 / 2,
        0,  # horizontal
        - 1 / 2,
        - 1 / np.sqrt(2),
        - np.sqrt(3) / 2,
        - 1,  # vertical
        - np.sqrt(3) / 2,
        - 1 / np.sqrt(2),
        - 1 / 2,
        0  # horizontal
    ],
    'cos x': [
        1, # horizontal
        np.sqrt(3) / 2,
        1 / np.sqrt(2),
        1 / 2,
        0, # vertical
        - 1 / 2,
        - 1 / np.sqrt(2),
        - np.sqrt(3) / 2,
        - 1, # horizontal,
        - np.sqrt(3) / 2,
        - 1 / np.sqrt(2),
        - 1 / 2,
        0, # vertical
        1 / 2,
        1 / np.sqrt(2),
        np.sqrt(3) / 2,
        1 # horizontal
    ],
    'sec x': [
        1,
        2 / np.sqrt(3),
        np.sqrt(2),
        2,
        np.NaN,
        - 2,
        - np.sqrt(2),
        - 2 / np.sqrt(3),
        - 1,
        - 2 / np.sqrt(3),
        - np.sqrt(2),
        - 2,
        np.NaN,
        2, np.sqrt(2),
        2 / np.sqrt(3),
        1
    ],
    'cosec x': [
        np.NaN, # horizontal
        2,
        np.sqrt(2),
        2 / np.sqrt(3),
        1, # vertical
        2 / np.sqrt(3),
        np.sqrt(2),
        2,
        np.NaN,
        -2, # horizontal
        - np.sqrt(2),
        - 2 / np.sqrt(3),
        -1,
        -2 / np.sqrt(3),
        - np.sqrt(2),
        -2,
        np.NaN,
    ]

}, index=[
    0,  # horizontal
    np.pi / 6,
    np.pi / 4,
    np.pi / 3,
    np.pi / 2,  # vertical
    2 * np.pi / 3,
    3 * np.pi / 4,
    5 * np.pi / 6,
    np.pi,  # horizontal
    7 * np.pi / 6,
    5 * np.pi / 4,
    4 * np.pi / 3,
    3 * np.pi / 2,  # vertical
    5 * np.pi / 3,
    7 * np.pi / 4,
    11 * np.pi / 6,
    2 * np.pi, # horizontal
]
)

df.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 5
#
# Prove that $1 + \tan^2 x = \sec^2 x$.
#
# ---
#
# Using the Pythagorean identity $\sin^2 x + \cos^2 x \equiv 1$.
#
# $$
# \begin{align}
# &1 + \tan^2 x \\
# &= 1 + \frac{\sin^2 x}{\cos^2 x} \\
# &= \frac{\cos^2 x}{\cos^2 x} + \frac{\sin^2 x}{\cos^2 x} \\
# &= \frac{\sin^2 x + \cos^2 x}{\cos^2 x} \\
# &= \frac{1}{\cos^2 x} \\
# &= \sec^2 x \\
# \end{align}
# $$

# %% [markdown]
# ### 6
#
# First, a Pythagorean identity for $\operatorname{cosec}$.
#
# $$
# \operatorname{cosec} x \equiv \frac{1}{\sin}
# $$
#
# So:
#
# $$
# \begin{align}
# \sin^2 x + \cos^2 x &= 1 \\
# \frac{\sin^2 x}{\sin^2 x} + \frac{\cos^2 x}{\sin^2 x} &= \frac{1}{\sin^2 x} \\
# 1 + \cot^2 x &= \frac{1}{\sin^2 x} \\
# \therefore \operatorname{cosec}^2 x &= 1 + \cot^2 x
# \end{align}
# $$
#
# Then for $\cot$.
#
# $$
# \operatorname{cot} x \equiv \frac{1}{\tan} \equiv \frac{\cos}{\sin}
# $$
#
# We can re-arrange our Pythagorean identity for $\operatorname{cosec}$ in terms of $\cot$:
#
# $$
# \begin{align}
# \operatorname{cosec}^2 x &\equiv 1 + \cot^2 x \\
# \therefore \cot^2 x &\equiv \operatorname{cosec}^2 x - 1
# \end{align}
# $$

# %% [markdown]
# ### 7
#
# Determine all possible values of $\cos x$ if $\tan x$ has the following values
#
# a) $\tan x = 1$
# b) $\tan x = -1$
# c) $\tan x = \sqrt{3}$
# d) $\tan x = \frac{1}{\sqrt{3}}$
# e) $\tan x = 0$
#
# ---
#
# We can think about this problem just in terms of the unit circle, because $\tan x$ of any angle inside any circle represents the same ratio between the horizontal and vertical components.
#
# And the horizontal and vertical components themselves are just $\sin x$ and $\cos x$ multiplied by the same factor, $r$.
#
# Linking back to previous chapters, we know that all circles are *dilations* of the unit circle, that dilation is an *isometry* and so it *preserves distance*.
#
# $\tan x$ is just the ratio of two distances that vary in exactly the same way under dilation.
#
# So it's no surprise that we can find _all_ possible values of $\cos x$ given just $\tan x$ inside any circle.
#
# a) $\frac{1}{\sqrt{2}}$ and $-\frac{1}{\sqrt{2}}$
# b) $-\frac{1}{\sqrt{2}}$ and $\frac{1}{\sqrt{2}}$
# c) $\frac{1}{2}$ and $-\frac{1}{2}$
# d) $\frac{\sqrt{3}}{2}$ and $-\frac{\sqrt{3}}{2}$

# %% [markdown]
# ### 8
#
# Determine all possible values of $\sin x$ in each one of the cases of Exercise 7.
#
# a) $\frac{1}{\sqrt{2}}$ and $-\frac{1}{\sqrt{2}}$
# b) $-\frac{1}{\sqrt{2}}$ and $\frac{1}{\sqrt{2}}$
# c) $\frac{\sqrt{3}}{2}$ and $-\frac{\sqrt{3}}{2}$
# d) $\frac{1}{2}$ and $-\frac{1}{2}$
# e) $0$

# %% [markdown]
# ### 9
#
# You are looking at a tall building from a distance of $500$ft.  The angle formed by the base of the building, your eyes, and the top of the building has
#
# a) $\frac{\pi}{4}$ radians
# b) $\frac{\pi}{3}$ radians
# c) $\frac{\pi}{6}$ radians
#
# Find the height of the building
#
# ---
#
# a) $500$ ft
# b) $500\sqrt{3}$ ft
# c) $\frac{500\sqrt{3}}{3}$ ft

# %% [markdown]
# ## 10
#
# A balloon $B$ starts from a point $P$ on earth and goes straight up.  An observer $O$ stands at a distance of $500$ft from $P$.  After $20$ min, the angle $\theta$ formed by $P$, $O$, $B$ has
#
# a) $\frac{\pi}{3}$ radians
# b) $\frac{\pi}{4}$ radians
# c) $\frac{\pi}{6}$ radians
#
# Find the height of the balloon at that time.
#
# ---
#
# a) $500\sqrt{3}$ ft
# b) $500$ ft
# c) $\frac{500\sqrt{3}}{3}$ ft

# %% [markdown]
# ### 11
#
# A boat $B$ starting from a point $P$ moves along a straight river.  A man $M$ stands $\frac{1}{2}$ mi from $P$ on the line through $P$ perpendicular to the river.  After $5$ hr, the boat has travelled $10$ mi.  Let $\theta$ be the angle $\angle BMP$.  Find
#
# a) $\cos \theta$
# b) $\sin \theta$
# c) $\tan \theta$
#
# at that time.
#
# ---
#
# a) $\frac{1}{2\sqrt{100.25}$
# b) $\frac{10}{\sqrt{100.25}}$
# c) $\frac{\frac{10}{\sqrt{100.25}}}{\frac{1}{2\sqrt{100.25}} = \frac{20\sqrt{100.25}}{\sqrt{100.25}} = 20$

# %% [markdown]
# A billiard ball table is rectangular, and its sides have $10$ ft and $7$ ft, respectively.  A billiard ball is hit starting at a point $P$ on one side as drawn on the picture.  It hits the next side at $Q$, bounces off, hits the third side at $M$, bounces off, and hits the fourth side at $N$.  Each time it bounces off a side, the angle of approach to this side has the same measure as the angle of departure.  Let $\theta$ be the first angle of departure as drawn in Fig. 11-28.
#
# _Diagram [here](https://www.docdroid.net/K1VENuF/basic-mathematics-serge-lang-pdf#page=287)_
#
# Assume that $P$ is at a distance $6$ ft from the corner $O$.
#
# ### 12
#
# Assume that $\theta$ has $30°$.  Find:
#
# a) $d(O, Q)$
# b) $d(P, Q)$
# c) $d(Q, B)$
# d) $d(B, M)$
# e) $d(Q, M)$
# f) $d(M, C)$
# g) $d(M, N)$
#
# ---
#
# a) $d(O, Q) = 2 \sqrt{3}$
# b) $d(P, Q) = 4 \sqrt{3}$
# c) $d(Q, B) = 7 - 2\sqrt{3}$
# d) $d(B, M) = 7\sqrt{3} - 6$
# e) $d(Q, M) = 14 - 4\sqrt{3}$
# f) $d(M, C) = 16 - 7\sqrt{3}$
# g) $d(M, N) = \frac{32\sqrt{3} - 42}{3}$

# %% [markdown]
# ## 13
#
# Repeat the problem for (a) through (g) of Exercise 12 if $\tan \theta = \frac{1}{2}$.
#
# ---
#
# a) $d(O, Q) = r \sin \theta$.  We have $d(O, P) = 6 = r \cos \theta$, and $\tan \theta = \frac{1}{2} = \frac{r \sin \theta\}{r \cos \theta}$. So $\frac{r \sin \theta}{6} = \frac{1}{2}$ and therefore $r \sin \theta = \frac{1}{2} \cdot 6 = 3$.  Finally, $d(O, Q) = 3$.
# b) By Pythagoras, $d(O, Q) = \sqrt{6^2 + 3^2} = \sqrt{45} = 3\sqrt{5}$.
# c) $d(Q, B) = d(O, B) - d(O, Q) = 7 - 4 = 3$.
# d) $d(B, M) = r \sin \theta_2$.  We can work out $\sin \theta_2$ from $\triangle{POQ}$: $\sin_\theta_2 = \frac{3 \sqrt{5}}{5}$.  And we can calculate $r$ using the known side length $d(Q, B) = 3$: $r \cos \theta_2 = 3, \cos \theta_2 = \frac{1}{\sqrt{5}}, so r = \frac{3}{\frac{1}{\sqrt{5}}} = 3 \sqrt{5}$. Pulling it all together, $d(B, M) = r \sin \theta_2 = \frac{3 \sqrt{5} \cdot 3 \sqrt{5}}{5} = 9$.
# e) $d(Q,M) = r$ from the previous question = $3\sqrt{5}$.
# f) $d(M, C) = 10 - d(B, M) = 10 - 9 = 1$.
# g) Let the measure of the angle denoted by $?$ in the diagram be $\theta_3$.  $d(M, N) \cos \theta_3 = 1 \implies d(M, N) = \frac{1}{\cos \theta_3}$.  $3\sqrt{5} \cos \theta_3 = 9 \implies \cos \theta_3 = \frac{3}{\sqrt{5}}$. $\therefore d(M, N) = \frac{1}{\frac{3}{\sqrt{5}}} = \frac{\sqrt{5}}{3}$.
#
# _I really liked this exercise.  Having to compute the side lengths while only knowing the values of the angle's trigonometric functions was really satisfying._

# %% [markdown]
# ## 14
#
# Find the general formula for
#
# a) $d(O, Q)$
# b) $d(P, Q)$
# c) $d(Q, M)$
# d) $d(Q, B)$
# e) $d(B, M)$
#
# in terms of $\tan \theta$.
#
# ---
#
# a) \begin{align}d(O, Q) &= r \sin \theta$ \\
# $\tan \theta &= \frac{r \sin \theta}{r \cos \theta} \\
# &= \frac{r \sin \theta}{6}$ \\
# $r \sin \theta &= 6 \tan \theta \\
# \therefore d(O, Q) &= 6 \tan \theta
# \end{align}
#
# b) There are two ways we could go about this.
#
# (1) Use Pythagoras' theorem to see that $d(P,Q) = \sqrt{6^2 + (6\tan \theta)^2} = \sqrt{6^2(\tan^2 \theta + 1} = 6\sqrt{\tan^2 \theta + 1}$.
#
# (2) Re-arrange the finding from (a) that $r \sin \theta = 6 \tan \theta$ to $r = \frac{6 \tan \theta}{\sin \theta} = \frac{6 \frac{\sin \theta}{\cos \theta}}{\sin \theta} = \frac{6}{\cos \theta} = 6 \sec \theta = 6 \sqrt{\sec^2 \theta}$, then substitute the Pythagorean identity $\sec^2 \theta \equiv \tan^2 \theta + 1$ to get $6 \sqrt{\tan^2 \theta + 1}$.
#
# Both use the Pythagorean identity 'under the hood', part (2) requires more algebraic judo than (1), but I think it's nice to pick an algebraic target and re-arrange a previously found result to get there.
#
# c) $\triangle OPQ$ and $\triangle BMQ$ are *similar* because $\theta = \frac{\pi}{2} - \frac{\pi}{4} - \theta_2 = ?$.  Because they're similar, they're related by a dilation, and so the ratio of $d(O, Q)$ to $d(Q, B)$ is preserved.  So $\frac{d(P, Q)}{d(O, Q)} = \frac{d(Q, M)}{d(Q, B)} \implies \frac{6\sqrt{\tan^2 \theta + 1}}{6 \tan \theta} = \frac{d(Q, M)}{7 - 6 \tan \theta}$.  Which finally gives us the gnarly expression $d(Q, M) = \frac{(7 - 6 \tan \theta)(\sqrt{\tan^2 \theta + 1})}{\tan \theta}$.
#
# d) $d(Q, B) = 7 - 6 \tan \theta$.
#
# e) Using the same principal of similar triangles, $d(B, M)$ is to $d(P, Q)$ as $d(Q, B)$ is to $d(O, Q)$.  Setting this up in an equation gives us $\frac{d(B, M)}{d(P, Q)} = \frac{d(Q, B)}{d(O, Q)} \implies \frac{d(B,M)}{6} = \frac{7 - 6 \tan \theta}{6 \tan \theta} \implies d(B, M) = \frac{7 - 6\tan \theta}{\tan \theta}$.

# %% [markdown]
# ### 15
#
# Find the general formula for the distances of Exercise 12 (a) through (e) in terms of $\sin \theta$.
#
# ---
#
# a) $d(O, Q) = d(P, Q) \cdot \sin \theta$.
#
# We need to find an expression for $r$ in terms of $\sin \theta$.
#
# We know that $d(O, P) = d(P, Q)  \cdot  \cos \theta = 6$, so $d(P, Q) = \frac{6}{\cos \theta}$.
#
# We can take the square of $d(P, Q)$, use the Pythagorean identity to convert $\cos^2 \theta$ to $\sin^2 \theta$, then take the square root.
#
# $$
# \begin{align}
# d(P, Q)^2 &= \frac{6^2}{\cos^2 \theta} = \frac{6^2}{1 - \sin^2 \theta} \\
# d(P, Q) &= \frac{6}{\sqrt{1 - \sin^2 \theta}}
# \end{align}
# $$
#
# Therefore $d(O,Q) = \frac{6\sin \theta}{\sqrt{1 - \sin^2 \theta}}$.
#
# b) $d(P, Q) = \frac{6}{\sqrt{1 - \sin^2 \theta}$ from our working for (a).
# c) $d(Q, B) = 7 - d(O, Q) = 7 - \frac{6\sin \theta}{\sqrt{1 - \sin^2 \theta}} = \frac{7\sqrt{1 - \sin^2 \theta} - 6 \sin \theta}{\sqrt{1 - \sin^2 \theta}}$.
# d) $$\begin{align}
# \frac{d(B, M)}{6} &= \frac{d(O, Q)}{d(Q, B)} \\
#  d(B, M) &= 6 \cdot \frac{\frac{6\sin \theta}{\sqrt{1 - \sin^2 \theta}}}{ \frac{7\sqrt{1 - \sin^2 \theta} - 6 \sin \theta}{\sqrt{1 - \sin^2 \theta}} } \\
#  &= 6 \cdot \frac{36 \sin \theta}{7\sqrt{1 - \sin^2 \theta} - 6 \sin \theta} \\
#  \end{align}
#  $$
# e) $$
# \begin{align}
#     d(Q, M) &= 6 \cdot \frac{d(P, Q)}{d(B, M)} \\
#     &= 6 \cdot \frac{ \frac{6}{\sqrt{1 - \sin^2 \theta} }}{ 6 \cdot \frac{36 \sin \theta}{7\sqrt{1 - \sin^2 \theta} - 6 \sin \theta} } \\
#     &= \cdot \frac{6 \cdot 7\sqrt{1 - \sin^2 \theta} - 6 \sin \theta}{36 \sin \theta \cdot \sqrt{1 - \sin^2 \theta} } \\
#     &= \frac{7\sqrt{1 - \sin^2 \theta} - 6 \sin \theta}{6 \sin \theta \sqrt{1 - \sin^2 \theta}}
# \end{align}
# $$
# f) $d(M, C) = 10 - d(M, B) = 10 - 6 \cdot \frac{36 \sin \theta}{7\sqrt{1 - \sin^2 \theta} - 6 \sin \theta}$
# g) d(M, N)
