# %%
from lib.trigonometry import sine, cosine, pi_approx
from lib.points import points
from matplotlib import pyplot as plt

# %% [markdown]
# # §3 - The graphs
#
# [https://www.docdroid.net/K1VENuF/basic-mathematics-serge-lang-pdf#page=268]()
#
# ## The big ideas

# %% [markdown]
# ## Exercises
#
# ### 1
#
# Make a similar study of cosine, and draw its graph.

# %%
cosine_points = points(cosine, [-(2 * pi_approx()), 2 * pi_approx()])
plt.plot(*zip(*cosine_points))

# %% [markdown]
# ### 2
#
# Sketch the graph of $\sin 2x$, i.e. all points whose coordinates are $(x, \sin 2x)$.
#
# ---

# %%
sin2x = lambda x: sine(2 * x)

sin2x_points = points(sin2x, [-(2 * pi_approx()), 2 * pi_approx()])
plt.plot(*zip(*sin2x_points))

# %% [markdown]
# ## 3
#
# Sketch the graphs, i.e. all pairs $(x, y)$ when $y$ is given by:
# a) $y = \sin(-x)$
# b) $y = \sin 3x$
# c) $y = \cos 2x$
# d) $y = \cos 3x$
# e) $y = \sin 4x$
# f) $y = \cos 4x$
# g) $y = \cos (-x)$
# h) $y = \sin 5x$
# i) $y = \cos 5x$

# %%
# (a)
sin_minus_x = lambda x: sine(-x)
sin_minus_x_points = points(sin_minus_x, [-(2 * pi_approx()), 2 * pi_approx()])
plt.plot(*zip(*sin_minus_x_points))

# %%
# (b)
sin3x = lambda x: sine(3 * x)
sin3x_points = points(sin3x, [-(2 * pi_approx()), 2 * pi_approx()])
plt.plot(*zip(*sin3x_points))

# %%
# (c)
cos2x = lambda x: cosine(2 * x)
cos2x_points = points(cos2x, [-(2 * pi_approx()), 2 * pi_approx()])
plt.plot(*zip(*cos2x_points))

# %%
# (d)
cos3x = lambda x: cosine(3 * x)
cos3x_points = points(cos3x, [-(2 * pi_approx()), 2 * pi_approx()])
plt.plot(*zip(*cos3x_points))

# %%
# (e)
sin4x = lambda x: sine(4 * x)
sin4x_points = points(sin4x, [-(2 * pi_approx()), 2 * pi_approx()])
plt.plot(*zip(*sin4x_points))

# %%
# (f)
cos4x = lambda x: cosine(4 * x)
cos4x_points = points(cos4x, [-(2 * pi_approx()), 2 * pi_approx()])
plt.plot(*zip(*cos4x_points))

# %%
# (g)
cos_minus_x = lambda x: cosine(-x)
cos_minus_x_points = points(cos_minus_x, [-(2 * pi_approx()), 2 * pi_approx()])
plt.plot(*zip(*cos_minus_x_points))

# %%
# (h)
sin5x = lambda x: sine(5 * x)
sin5x_points = points(sin5x, [-(2 * pi_approx()), 2 * pi_approx()])
plt.plot(*zip(*sin5x_points))

# %%
# (i)
cos5x = lambda x: cosine(5 * x)
cos5x_points = points(cos5x, [-(2 * pi_approx()), 2 * pi_approx()])
plt.plot(*zip(*cos5x_points))
