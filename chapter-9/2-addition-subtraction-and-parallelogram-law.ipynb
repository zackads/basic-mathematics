# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Circle

# %% [markdown]
# # §2 - Addition, subtraction, and the parallelogram law
#
# https://www.docdroid.net/K1VENuF/basic-mathematics-serge-lang-pdf#page=234
#
# Analytic geometry lets us represent mathematical objects in lines, planes and spaces where they are subject to laws consistent with operations on numbers.
#
# This chapter is concerned with performing arithmetic on geometric objects.
#
# ## The big ideas
#
# ### Addition
#
# We can sum two points in a plane.
#
# Given $A = (a_1, a_2)$ and $B = (b_1, b_2)$, we define A + B as
#
# $$ A + B = (a_1 + b_1, a_2 + b_2) $$
#
# The sum of two or more ordered pairs is the sum of their corresponding real numbers.
#
# The analytic properties of adding numbers also apply to adding points: commutativity, associativity, the zero element and additive inverse are all exactly the same.
#
# We can map the analytic addition of two ordered pairs to the geometric equivalent by plotting the operation on a plane:

# %%
def add(point1, point2):
    return (point1[0] + point2[0], point1[1] + point2[1])

A = (1, 2)
B = (3, 1)
AplusB = add(A, B)
O = (0, 0)

plt.plot(*O, 'x')
plt.plot(*A, 'o')

plt.annotate('A', A)
plt.annotate('O', O)

plt.plot(*B, 'o')
plt.plot(*AplusB, 'o')

plt.annotate('B', B)
plt.annotate('A + B', AplusB)

plt.plot([A[0], AplusB[0]], [A[1], AplusB[1]])
plt.plot([O[0], B[0]], [O[1], B[1]])
plt.plot([O[0], A[0]], [O[1], A[1]])
plt.plot([B[0], AplusB[0]], [B[1], AplusB[1]])

# %% [markdown]
# ### Subtraction
#
# Subtraction is similar: (Remember, subtraction is the addition of the additive inverse: $A - B = A + (-B)$.  So in the Python below, I've defined subtraction of two points in terms of addition.)

# %%
def scale(point, factor):
    return tuple(map(lambda n : n * factor, point))

def subtract(minuend, subtrahend):
    """
    Subtraction is the addition of the additive inverse,
    and the additive inverse is the scaling by -1
    """
    return add(minuend, scale(subtrahend, -1))

O = (0, 0)
A = (1, 2)
B = (3, 1)
OminusB = subtract(O, B)
AminusB = subtract(A, B)

plt.plot(*O, 'x')
plt.plot(*A, 'o')
plt.plot([O[0], B[0]], [O[1], B[1]])
plt.annotate('A', A)
plt.annotate('O', O)

plt.plot(*B, 'o')

plt.plot([A[0], AminusB[0]], [A[1], AminusB[1]])
plt.annotate('B', B)
plt.plot(*OminusB, 'o')
plt.annotate('-B', OminusB)
plt.annotate('A - B', AminusB)

plt.plot(*AminusB, 'o')
plt.plot([OminusB[0], O[0]], [OminusB[1], O[1]], '--')
plt.plot([O[0], A[0]], [O[1], A[1]], '--')
plt.plot([OminusB[0], AminusB[0]], [OminusB[1], AminusB[1]], '--')
plt.plot([A[0], B[0]], [A[1], B[1]])
plt.plot([O[0], AminusB[0]], [O[1], AminusB[1]])

# %% [markdown]
# ### Translation
#
# Addition or subtraction of one point to/from another, such that the result is a new point in the same plane, is called **translation**.  Translation can be represented symbolically with the association $P \to P + A$, abbreviated to $T_A$.
#
# Translation is the _geometric_ operation on a _point_, whereas _addition_ is the _analytic_ operation on an _ordered pair_.  Analytic geometry shows us that they are the same thing.  Lang states this:
#
# > We see that we have been able to define one more of the intuitive geometric notions within our system of coordinates, based only on properties of numbers.
#
# ### Distance
#
# We can describe distance as a difference between two points, i.e. a subtraction.
#
# By convention, we choose to use the absolute value or magnitude sign as shorthand for the distance of a point from the origin:
#
# $$d(A, O) = |A - O| = |A|$$
#
# (The origin is the zero point, so subtracting it has no effect.)
#
# Look back at the previous plot of $A - B$.  See that:
#
# $$d(A, B) = d(A - B, O) = |(A - B) - O| = |A - B|$$
#
# Hence, the distance between $A$ and $B$, $d(A, B)$, is $|A - B|$.

# %% [markdown]
# ## Exercises
#
# Exercises 1 to 10, which require plotting addition and subtraction operations on points, are skipped

# %% [markdown]
# ### 11
#
# Let $T_A$ be a translation by $A$.  Prove that it is an isometry, in other words, that for any pair of points $P$, $Q$, we have
#
# $$d(P, Q) = d(T_A(P), T_A(Q))$$
#
# ---
#
# $T_A(P) = T + A$ by the definition of a translation.
#
# So $d(T_A(P), T_A(Q)) = d(P + A, Q + A)$
#
# Using the expression of distance in modulus notation at the bottom of p222, we can express this as
#
# $d(P + A, Q + A) = |(P + A) - (Q + A)|$
#
# Simplifying:
#
# $|(P + A) - (Q + A)| = |P + A - Q - A| = |P - Q|$
#
# Which is the same as $d(P, Q)$, again by the same modulus notation on p222.
#
# Therefore, $d(P, Q) = d(T_A(P), T_A(Q))$ and the theorem is proved.

# %% [markdown]
# ### 12
#
# Let $D(r, A)$ denote the disc of radius $r$ centered at $A$.  Show that $D(r, A)$ is the translation by $A$ of the disc $D(r, O)$ of radius $r$ centered at $O$.
#
# ---
#
# It suffices to prove that the centre of $D(r, A)$, $A$, is the translation by $A$ of the point $O$, or:
#
# $$A = T_A(O)$$
#
# Because if $A = T_A(O)$ then every point within $r$ of $A$ is, by definition, the disc $D(r, A)$, and so the whole disc is translated from $O$.
#
# $T_A(O) = O + A$ (by the definition of translation on [p221](https://www.docdroid.net/K1VENuF/basic-mathematics-serge-lang-pdf#page=237)).
#
# $O$ is the zero point $(0, 0)$, so its addition is meaningless.
#
# Hence, $T_A(0) = O + A = A$.
#
# So the point $A$ is the translation by $A$ of $O$.
#
# Therefore, the disc $D(r, A)$ is the translation by $A$ of the disc $D(r, O)$.

# %% [markdown]
# ## 13
#
# Let $S(r, P)$ denote the circle of radius $r$ centered at $P$.
#
# a) Show that the reflection of this circle through $O$ is again a circle.  What is the center of the reflected circle?
#
# b) Show that the reflection of the disc $D(r, P)$ through $O$ is a disc.  What is the center of this reflected disc?
#
# ---
#
# a) Reflection through the origin is identical to the scaling of an object by $-1$.
#
# Let $M$ be a point on the circle $S(r, P)$.
#
# The reflection of $M$ is the scaling of $M$ by $-1$, i.e. $R(M) = -M$.
#
# The reflection of the centre of the circle, $P$, is the scaling of $P$ by $-1$, i.e. $R(P) = -P$.
#
# To prove that the reflection of $S(r, P)$ is a circle, it suffices to show that the distance between the centre, $P$,  and any point on the circle, $M$, is the same in both the original and the reflection.  I.e. that:
#
# $$d(M, P) = d(-M, -P) = r$$
#
# We know that distance between two points is the magnitude of their difference:
#
# $$d(M, P) = |M - P|$$
#
# This also applies to the reflection:
#
# $$d(-M, -P) = |-M - (-P)|$$
#
# Which we can apply the distributive property of multiplication over subtraction to show that
#
# $$= |-M - (-P)| = |-(M - P)|$$
#
# Which, because the modulus operator disregards that sign, we can write as follows:
#
# $$|-(M-P)| = |M-P|$$
#
# Which is the same as for $d(M, P)$.
#
# Hence, $d(M, P) = d(-M, -P)$, and so the reflection of the circle $S(r, P)$, $S(r, -P)$, is itself a circle, as was to be proved.
#
# b) Let $M$ be a point on the disc $D(r, P)$.
#
# Let $R$ be reflection through the origin, $O$, such that $R(M) = -M$.
#
# The reflection of the disc $D(r, P)$ is a disc if, for every point, $M$, on the disc, $d(M, P) = d(R(M), R(P)$.
#
# We know that $d(M, P) = d(R(M), R(P))$ because $R$ is an isometry, meaning it preserves distances.
#
# Therefore, the reflection of the disc $D(r, P)$ through $O$ is a disc at centre $R(P)$.

# %% [markdown]
# ### 14
#
# Let $P$, $Q$ be points.  Write $P = Q + A$, where $A = P - Q$.  Define the **reflection of $P$ through $Q$** to be the point $Q - A$.  If $R_Q$ denotes reflection through $Q$, then we have $R_Q(P) = 2Q - P$. (Why?)
#
# Draw the picture, showing $P$, $Q$, $A$, and $Q - A$ to convince yourself that this definition corresponds to our geometric intuition.
#
# ---
#
# $R_Q(P) = 2Q - P$ because substituting $A = P - Q$ into $R_Q(P) = Q - A$ gives us:
#
# $$R_Q(P) = Q - A = Q - (P - Q) = Q - P + Q = 2Q - P$$

# %%
O = (0, 0)
P = (1, 3)
Q = (5, 4)
A = subtract(P, Q)
QminusA = subtract(Q, A)
TwoQ = scale(Q, 2)

plt.plot(*O, 'x')
plt.plot(*P, 'o')
plt.plot(*Q, 'o')
plt.plot(*A, 'o')
plt.plot(*QminusA, 'o')
plt.plot(*TwoQ, 'o')

plt.plot([O[0], P[0]], [O[1], P[1]])
plt.plot([TwoQ[0], QminusA[0]], [TwoQ[1], QminusA[1]])
plt.plot([P[0], QminusA[0]], [P[1], QminusA[1]], "--")
plt.plot([O[0], TwoQ[0]], [O[1], TwoQ[1]], "--")

plt.annotate("O", O)
plt.annotate("P", P)
plt.annotate("Q", Q)
plt.annotate("A", A)
plt.annotate("Q - A or 2Q - P", QminusA)
plt.annotate("2Q", TwoQ)
# Out:
# Text(10, 8, '2Q')

# %% [markdown]
# ## 15
#
# a) Prove that reflection through a point $Q$ can be expressed in terms of reflection through $O$, followed by a translation.
#
# b) Let $T_A$ be translation by $A$, and $R_O$ reflection with respect to the origin.  Prove that the composite $T_A \circ R_O$ is equal to $R_Q$ for some point $Q$.  Which one?
#
# ---
#
# a) Look at the previous plot, where $P$ reflected in $Q$ is $Q - A$ or $2Q - P$.
#
# We can achieve the same thing by first reflecting $P$ in $O$, giving $-P$, then translating $-P$ by $2Q$, giving $-P + 2Q$.
#
# Therefore, reflection through the point $Q$ can be expressed as a reflection through $O$ followed by a translation of $2Q$.
#
# b) Let's illustrate the two functions separately on an example point, $P$.
#
# $$T_A(P) = P + A$$
#
# $$R_O(P) = -P$$
#
# So, composed together, $T_A(P) \circ R_O(P) = -P + A$.
#
# The question wants us to prove that this is equal to $R_Q(P)$.  We already have an expression for $R_Q(P)$ from part (a) of the question, so let's equate our composite example with that.
#
# $$T_A(P) \circ R_O(P) = R_Q(P)$$
#
# $$-P + A = 2Q - P$$
#
# The $-P$ terms cancel out:
#
# $$A = 2Q$$
#
# Re-arranging in terms of $Q$:
#
# $$Q = \frac{A}{2}$$
#
# So $T_A(P) \circ R_O(P) = R_Q(P)$ for $Q = \frac{A}{2}$.
#
# In plain English: reflection of a point through $Q$ is equal to reflection through the origin followed by a translation, $A$, when $Q$ is the point halfway between the origin and $A$.

# %%
O = (0, 0)
P = (1, 3)
Q = (5, 4)
A = subtract(P, Q)
QminusA = subtract(Q, A)
TwoQ = scale(Q, 2)
reflectionOfQInP = subtract(Q, A)

plt.plot(*O, 'x')
plt.plot(*P, 'o')
plt.plot(*Q, 'o')
plt.plot(*reflectionOfQInP, 'o')
plt.plot(*A, 'o')

plt.annotate("O", O)
plt.annotate("P", P)
plt.annotate("Q", Q)
plt.annotate("R_Q(P)", reflectionOfQInP)
plt.annotate("A", A)
# Out:
# Text(-4, -1, 'A')

# %% [markdown]
# ## 16
#
# a) Let $r$ be a positive number.  Give an analytic definition of dilation by $r$ with respect to a point $Q$, and denote this dilation by $F_{r,Q}$.  To give this definition, look at Exercise 14.  You may also want to look at the discussion about line segments in §4.  If $P$ is a point, draw the picture with $O$, $P$, $Q$, $P - Q$, and $F_{r,Q}(P)$.
#
# b) From your definition, it should be clear that $F_{r,Q}$ can be obtained as a composite of dilation with respect to $O$, and a translation.  Translation by what point?
#
# ---
#
# Let $P$, $Q$ be points.  Define the dilation by $r$ with respect to point $Q$ to be the point $r(P - Q) + Q$.  If $F_{r,Q}$ denotes dilation through $r$ with respect to $Q$ then we have $F_{r,Q}(P) = r(P - Q) + Q$.
#
# What's happening here?
#
# 1. First, translate $P$ and $Q$ such that $Q$ is at the origin: $(P - Q)$
# 2. Then, scale the result with respect to the origin: $r(P - Q)$
# 3. Finally, translate back again to the original position: $r(P - Q) + Q$

# %%
O = (0, 0)
P = (1, 3)
Q = (5, 4)
r = 1.5
PminusQ = subtract(P, Q)
F_rQP = add(scale(PminusQ, r), Q)

plt.plot(*O, 'x')
plt.plot(*P, 'o')
plt.plot(*Q, 'o')
plt.plot(*PminusQ, 'o')
plt.plot(*scale(PminusQ, r), 'o')
plt.plot(*F_rQP, 'o')

plt.annotate('O', O)
plt.annotate('P', P)
plt.annotate('Q', Q)
plt.annotate('P - Q', PminusQ)
plt.annotate('r(P - Q)', scale(PminusQ, r))
plt.annotate('F_rQ(P)', F_rQP)
# Out:
# Text(-1.0, 2.5, 'F_rQ(P)')

# %% [markdown]
# b) Our definition of dilation of a point with respect to $Q$ is
#
# $$F_{r,Q}(P) = r(P - Q) + Q$$
#
# The question is telling us that this can be expressed as a composition of dilation with respect to $O$ and a translation, so
#
# $$F_{r,Q}(P) = rP + A$$
#
# We can equate these two expressions for $F_{r,Q}$ to find $A$ in terms of $r$ and $Q$.
#
# $$r(P - Q) + Q = rP + A \\
# rP - rQ + Q = rP + A \\
# -rQ + Q = A \\
# A = Q + rQ$$
#
# So, dilation of a point with respect to $Q$ is equivalent to dilation of $P$ with respect to the origin, followed by translation by $Q + rQ$, expressed symbolically as:
#
# $$F_{r,Q} = T_{Q+rQ}\circ F_{r,O}$$

# %% [markdown]
# ## 17
#
# Let $S(r, A)$ be the circle of radius $r$ and center $A$.  Show that the reflection of this circle through a point $Q$ is a circle.  What is the center of this reflected circle?  What is its radius?  Draw a picture.
#
# ---
#
# Let $M$ be a point on the circle $S(r, A)$.  The reflection of $M$ through $Q$ is
#
# $R_Q(M) = 2Q - M$
#
# Likewise, the reflection of the centre of the circle, $A$, is
#
# $R_Q(A) = 2Q - A$
#
# We know that
#
# $$d(M, A) = d(R_Q(M), R_Q(A)) = r$$
#
# because $R_Q$ is an isometry.
#
# ($R_Q$ is a composed of a translation and a reflection through the origin, both of which are isometries, and we know from previous chapters that any composition of isometries is itself an isometry.)
#
# Let $M'$ be a point on $R_Q(S(r, A))$.  We can reflect $M'$ through $Q$ like this
#
# $$R_Q(M') = 2Q - M' \\
# = 2Q - (2Q - M) \\
# = 2Q - 2Q + M \\
# = M$$
#
# We have shown that every point on the circle $S(r, A)$ has a reflection that is of distance $r$ from the reflection of its centre, and vice versa.
#
# Therefore, the reflection of $S(r, A)$ is a circle at centre $R_Q(A) = 2Q - A$ with radius $r$.

# %%
def reflect(point, q=(0,0)):
    """
    R_Q(P) = Q - (P - Q) = 2Q - P
    """
    return subtract(scale(q, 2), point)

r = 0.5
A = (0.5, 0.5)
Q = (0.4, 0.4)

circle = plt.Circle(A, 0.1, color='r')
reflection = plt.Circle(reflect(A, Q), 0.1, color='b')
plt.gca().set_aspect('equal')
plt.gca().add_patch(circle)
plt.gca().add_patch(reflection)
plt.plot(*Q, 'o')
plt.annotate('Q', Q)
plt.plot(*O, 'x')
plt.annotate('O', O)
# Out:
# Text(0, 0, 'O')

# %% [markdown]
# ## 19
#
# Let $F_r$ be dilation by a positive number $r$, with respect to $O$, and let $T_A$ by translation by $A$.
#
# a) Show that $F_r^{-1}$ is also a dilation.  By what number?
#
# b) Show that $F_r \circ T_A \circ F_r^{-1}$ is a translation.
#
# ---
#
# a) My initial intuition suggests $F_r^{-1}$ is a dilation by a factor of $-r$.  Substituting into the definition of the identity:
#
# $$(F_r \circ F_r^{-1})(P) = r(-rP) = -r^2P$$
#
# which is not the identity, so this is incorrect.
#
# It's clear now that $F_r^{-1}$ should be the inverse of multiplication, i.e. division by $r$ or, in geometric terms, dilation by a factor of $\frac{1}{r}$:
#
# $$(F_r \circ F_r^{-1})(P) = r(\frac{1}{r}P) = \frac{rP}{r} = P$$
#
# and
#
# $$(F_r^{-1} \circ F_r)(P) = \frac{1}{r}(rP) = \frac{rP}{r} = P$$
#
# So, $F_r^{-1}$ is a dilation by $\frac{1}{r}$.
#
# b)  From (a) we know that
#
# $$
# F_r \circ T_A \circ F_r^{-1} = F_r \circ T_A \circ F_\frac{1}{r}\\
# $$
#
# Let $P$ be a point in the plane.  Constructing an equation in $P$:
#
# $$(F_r \circ T_A \circ F_\frac{1}{r})(P) = r(\frac{P}{r} +A)$$
#
# Expanding the brackets:
#
# $$
# r(\frac{P}{r} + A) = \frac{rP}{r} + rA \\
# = P + rA
# $$
#
# The $+ rA$ term represents a translation by $rA$.
#
# Therefore, $(F_r \circ T_A \circ F_r^{-1})(P) = P + rA$ and so $(F_r \circ T_A \circ F_r^{-1})$ is equivalent to translation by $rA$.

# %% [markdown]
# ## 20
#
# Show that the composite of two translations is a translation.  If T_A \circ T_B = T_C, how would you express C in terms of A and B?
#
# ---
#
# Expressed separately, $T_A(P) = P + A$ and $T_B(P) = P + B$.
#
# Composed, then, $T_A \circ T_B = (P + B) + A = P + B + A$.
#
# Therefore, $T_C(P) = P + (B + A)$.
#
# The $+ (B + A)$ term represents a translation by $(B + A)$, hence the composite of two translations, $T_C$, is itself a translation.

# %% [markdown]
# ## 21
#
# Let $R$ be reflection through the origin.
#
# a) Show that $R^{-1}$ exists.
#
# b) Show that $R \circ T_A \circ R^{-1}$ is a translation.  By what?
#
# ---
#
# a) If $R^{-1}$ exists, then $R \circ R^{-1} = I$.
#
# Let $P$ be a point in the plane.
#
# $$R{P} = -P$$
#
# Intuition suggests that the inverse operation of reflection is itself reflection, i.e. $R^{-1} = R$.  If that's true, then $R \circ R$ would be the identity.  Let's try that out.
#
# $$
# (R \circ R)(P) = R(R(P)) \\
# = R(-P) \\
# = -(-P) \\
# = P
# $$
#
# $R \circ R = R \circ R^{-1} = I$, therefore $R^{-1}$ exists.
#
# b) Let $P$ be a point on the plane.
#
# $$
# (R \circ T_A \circ R^{-1})(P) = -(-P + A) \\
# = -(-P) - A \\
# = P - A
# $$
#
# Therefore $R \circ T_A \circ R^{-1}$ is a translation by $-A$.

# %% [markdown]
# ## 22
#
# Let $A = (a_1, a_2)$ be a point.  Define its reflection through the $x$-axis to be the point $(a_1, -a_2)$.  Draw $A$ and its reflection through the $x$-axis in the following cases.
#
# a) $A = (1, 2)$
# b) $A = (-1, 3)$
# c) $A = (-2, -4)$
# d) $A = (5, -2)$

# %%
def reflectInX(point):
    return point[0], -point[1]

# (a)
plt.plot(*(1, 2), 'o')
plt.plot(*reflectInX((1, 2)), 'o')

# (b)
plt.plot(*(-1, 3), 'o')
plt.plot(*reflectInX((-1, 3)), 'o')

# (c)
plt.plot(*(-2, -4), 'o')
plt.plot(*reflectInX((-2, -4)), 'o')

# (d)
plt.plot(*(5, -2), 'o')
plt.plot(*reflectInX((5, -2)), 'o')

# %% [markdown]
# ## 23
#
# Prove that reflection through the $x$-axis is an isometry.
#
# ---
#
# Let $P$, $Q$ be points in the plane with coordinates $(x_p, y_p)$ and $(x_q, y_q)$ respectively.
#
# Let $R_x$ be reflection in the $x$-axis such that
#
# $$
# R_x(P) = R_x((x_p, y_p)) = (x_p, -y_p) \\
# R_x(Q) = R_x((x_q, y_q)) = (xp, -y_q)
# $$
#
# $R_x$ is an isometry if $d(P, Q) = d(R_x(P), R_x(Q))$ (by the definition of an isometry as distance-preserving).
#
# $$
# d(P, Q) = d((x_p, y_p), (x_q, y_q)) \\
# = \sqrt{(x_q - x_p)^2 + (y_q - y_p)^2}
# $$
#
# $$
# d(R_x(P), R_x(Q) = d((x_p, -y_p), (x_q, -y_p) \\
# = \sqrt{(x_q - x_p)^2 + (-y_q - (-y_p))^2} \\
# = \sqrt{(x_q - x_p)^2 + ((-1)(y_q - y_p))^2} \\
# = \sqrt{(x_q - x_p)^2 + (-1)^2(y_q - y_p)^2} \\
# = \sqrt{(x_q - x_p)^2 + (y_q - y_p)^2}
# $$
#
# $d(P, Q) = d(R_x(P), R_x(Q))$ and so $R_x$ is an isometry.

# %% [markdown]
# ## 24
#
# Define reflection through the $y$-axis in a similar way, and prove that it is an isometry.  Draw the points of Exercise 22, and their reflections through the $y$-axis.
#
# ---
#
# Define reflection in the $y$-axis to be $R_y$ such that
#
# $$R_y((x, y)) = (-x, y)$$
#
# for a given point with coordinates $(x, y)$.
#
# Let $P$, $Q$ be points in the plane with coordinates $(x_p, y_p)$ and $(x_q, y_q)$ respectively.
#
# $$
# d(P, Q) = d((x_p, y_p), (x_q, y_q)) \\
# = \sqrt{(x_q - x_p)^2 + (y_q - y_p)^2}
# $$
#
# $$
# d(R_y(P), R_y(Q)) = d((-x_p, y_p), (-x_q, y_p)) \\
# = \sqrt{(-x_q - (-x_p))^2 + (y_q - y_p)^2} \\
# = \sqrt{((-1)(x_q - x_p))^2 + (y_q - y_p)^2} \\
# = \sqrt{(-1)^2(x_q - x_p)^2 + (y_q - y_p)^2} \\
# = \sqrt{(x_q - x_p)^2 + (y_q - y_p)^2}
# $$
#
# $d(P, Q) = d(R_y(P), R_y(Q))$ and so $R_y$ is an isometry.

# %%
def reflectInY(point):
    return -point[0], point[1]

# (a)
plt.plot(*(1, 2), 'o')
plt.plot(*reflectInY((1, 2)), 'o')

# (b)
plt.plot(*(-1, 3), 'o')
plt.plot(*reflectInY((-1, 3)), 'o')

# (c)
plt.plot(*(-2, -4), 'o')
plt.plot(*reflectInY((-2, -4)), 'o')

# (d)
plt.plot(*(5, -2), 'o')
plt.plot(*reflectInY((5, -2)), 'o')

# %% [markdown]
# ## 25
#
# Recall that a **fixed point** of a mapping $F$ is a point $P$ such that $F(P) = P$.  Using the coordinate definition, determine the fixed points of
#
# a) a translation,
# b) reflection through $O$,
# c) reflection through an arbitrary point $P$,
# d) reflection through the $x$-axis and through the $y$-axis.
#
# Prove your assertions
#
# ---
#
# "Using the coordinate definition"
#
# a) Define $T_A$ to be a translation of a point $P$ by a point $A$ such that
#
# $$T_{(x_A, y_A)}(x_P, y_P) = (x_P + x_A, y_P + y_A)$$
#
# $T_A$ is fixed when $T_A(P) = P$.
#
# Written using the coordinate definition:
#
# $$(x_P + x_A, y_P + y_A) = (x_P + x_A)$$
#
# And approached piecewise by coordinate:
#
# $$
# x_P + x_A = x_P \\
# x_A = 0
# $$
#
# $$
# y_P + y_A = y_P \\
# y_A = 0
# $$
#
# Therefore, the fixed point of a translation, $T_A$, is any $P$ where $A = 0$.
#
# b) Define $R$ to be reflection through the origin such that
#
# $$R(P) = -P$$
#
# for some point $P$.
#
# The fixed point of $R$ is the origin, i.e. $R(O) = -O = O$.
#
# c) Define $R_P$ to be reflection through the point $P$ such that
#
# $$R_P(M) = P - (M - P) = 2P - M$$
#
# for some point $M$.
#
# The fixed point has to be where $M = P$, so that $2P - P = P$.
#
# So the fixed point of $R_P = P$.
#
# d) $R_x(P) = P$ for some point $P$ with coordinates $(x, 0)$ for any real $x$.  $R_y(P) = P$ for some point P with coordinates $(0, y)$ for any real $y$.

# %% [markdown]
# ## 26
#
# a) Let
#
# $E_1 = (1, 0)$ and $E_2 = (0, 1)$
#
# We call $E_1$ and $E_2$ the basic unit points of the plane.  Plot these points.  If $A = (a_1, a_2)$, prove that
#
# $$A = a_1E_1 + a_2E_2$$
#
# b) If $c$ is a number, what are the coordinates of $cE_1$, $cE2$.
#
# ---
#
# We can express $A$ as two perpendicular transformations from the origin:
#
# $$A = (O + (a_1, 0))) + (O + (a_2, 0)))$$
#
# Using the definition of multiplying a point by a scalar, we can factor out $a_1$ and $a_2$ from the points $(a_1, 0)$ and $(a_2, 0)$:
#
# $$A = (O + a_1(1, 0)) + (O + a_2(0, 1))$$
#
# We then notice that $E_1 = (1, 0)$ and $E_2 = (0, 1)$, which we substitute into the equation:
#
# $$A = (O + a_1E_1) + (O + a_2E_2)$$
#
# And then we cancel the $O$s because they represent the zero point:
#
# $$A = a_1E_1 + a_2E_2$$
#
# which was to be proved.
#
# b) $cE_1 = c(1, 0) = (c, 0)$. $cE_2 = c(0, 1) = (0, c)$.

# %% [markdown]
# ## 27
#
# Let $A = (2, 3)$.  Draw the points $A$, $A + E_1$, $A + E_2$, $A + E_1 + E_2$

# %%
A = (1, 2)
E_1 = (1, 0)
E_2 = (0, 1)

# A
plt.plot(*A, 'o')
plt.annotate('A', A)

# A + E_1
plt.plot(*add(A, E_1), 'o')
plt.annotate('A + E_1', add(A, E_1))

# A + E_2
plt.plot(*add(A, E_2), 'o')
plt.annotate('A + E_2', add(A, E_2))

# A + E_1 + E_2
plt.plot(*(add(add(A, E_1), E_2)), 'o')
plt.annotate('A + E_1 + E_2', (add(add(A, E_1), E_2)))
# Out:
# Text(2, 3, 'A + E_1 + E_2')

# %% [markdown]
# ## 28
#
# Let $A = (2, 3)$.  Draw the points $A$, $A + 3E_1$, $A + 3E_2$, $A + 3E_1 + 3E_2$.

# %%
A = (2, 3)

# A
plt.plot(*A, 'o')
plt.annotate('A', A)

# A + 3E_1
APlus3E1 = add(A, scale(E_2, 3))
plt.plot(*add(A, scale(E_1, 3)), 'o')
plt.annotate('A + 3E_1', add(A, scale(E_1, 3)))

# A + 3E_2
APlus3E2 = add(A, scale(E_2, 3))
plt.plot(*APlus3E2, 'o')
plt.annotate('A + 3E_1', APlus3E2)

# A + 3E_1 + 3E_2
APlus3E1Plus3E2 = add(APlus3E1, scale(E_1, 3))
plt.plot(*APlus3E1Plus3E2, 'o')
plt.annotate('A + 3E_1 + 3E_2', APlus3E1Plus3E2)
# Out:
# Text(5, 6, 'A + 3E_1 + 3E_2')
